# %% [markdown]
# # Experiments

# %%
from pandas import read_csv
from scipy.stats import poisson, norm, nbinom, gaussian_kde
from functions.experiment import experiment
from functions.rnaseq_data_generator import rna_seq_generator, generate_rnaseq_class, get_random_beta
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('Solarize_Light2')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-68ea082ebe0f> in <module>
#       1 from pandas import read_csv
#       2 from scipy.stats import poisson, norm, nbinom, gaussian_kde
# ----> 3 from functions.experiment import experiment
#       4 from functions.rnaseq_data_generator import rna_seq_generator, generate_rnaseq_class, get_random_beta
#       5 get_ipython().run_line_magic('load_ext', 'autoreload')
#
# ModuleNotFoundError: No module named 'functions'

# %% [markdown]
# ### Real data distribution

# %%
# Load data
samples = read_csv('../19NQ013_samples.csv')
samples = samples.set_index('genes')
samples.head()
# Out:
#                    OT_05  OT_17  OT_18  OT_21  OT_23  OT_33  OT_34  OT_62  \
# genes
# ENST00000632684.1      0      0      0      0      0      0      0      0
# ENST00000434970.2      0      0      0      0      0      0      0      0
# ENST00000448914.1      0      0      0      0      0      0      0      0
# ENST00000415118.1      0      0      0      0      0      0      0      0
# ENST00000631435.1      0      0      0      0      0      0      0      0
#
#                    OT_63  OT_64  ...  STA_14_CNI  STA_15_nonCNI  \
# genes                            ...
# ENST00000632684.1      0      0  ...           0              0
# ENST00000434970.2      0      0  ...           0              0
# ENST00000448914.1      0      0  ...           0              0
# ENST00000415118.1      0      0  ...           0              0
# ENST00000631435.1      0      0  ...           0              0
#
#                    STA_16_nonCNI  STA_17_CNI  STA_18_CNI  STA_19_CNI  \
# genes
# ENST00000632684.1              0           0           0           0
# ENST00000434970.2              0           0           0           0
# ENST00000448914.1              0           0           0           0
# ENST00000415118.1              0           0           0           0
# ENST00000631435.1              0           0           0           0
#
#                    STA_20_CNI  STA_21_CNI  STA_22_CNI  STA_23_CNI
# genes
# ENST00000632684.1           0           0           0           0
# ENST00000434970.2           0           0           0           0
# ENST00000448914.1           0           0           0           0
# ENST00000415118.1           0           0           0           0
# ENST00000631435.1           0           0           0           0
#
# [5 rows x 78 columns]

# %%
# Leave only OT, CR and STA
drop_list = []
for patient in samples.columns:
    if patient[:2] != 'OT':
        drop_list.append(patient)
genes = samples.index.values
samples = samples.drop(drop_list[0:], axis=1)
samples.head()
# Out:
#                    OT_05  OT_17  OT_18  OT_21  OT_23  OT_33  OT_34  OT_62  \
# genes
# ENST00000632684.1      0      0      0      0      0      0      0      0
# ENST00000434970.2      0      0      0      0      0      0      0      0
# ENST00000448914.1      0      0      0      0      0      0      0      0
# ENST00000415118.1      0      0      0      0      0      0      0      0
# ENST00000631435.1      0      0      0      0      0      0      0      0
#
#                    OT_63  OT_64  OT_65  OT_66  OT_67  OT_69  OT_71
# genes
# ENST00000632684.1      0      0      0      0      0      0      0
# ENST00000434970.2      0      0      0      0      0      0      0
# ENST00000448914.1      0      0      0      0      0      0      0
# ENST00000415118.1      0      0      0      0      0      0      0
# ENST00000631435.1      0      0      0      0      0      0      0

# %%
# Delete transcripts with zero expression
print('Number of all genes: ', samples.sum(axis=1).count())
print('Number of genes which have > 30 counts: ', (samples.sum(axis=1) > 30).value_counts())
print('Number of genes which have a least 5 counts in one of sample: ', (samples.max(axis=1) > 10).value_counts())
samples = samples[(samples.sum(axis=1) > 30) & (samples.max(axis=1) > 9)]
print('Number of all genes after data filtering: ', samples.sum(axis=1).count())
samples.head()
# Out:
# Number of all genes:  187626
# Number of genes which have > 30 counts:  False    135498
# True      52128
# dtype: int64
# Number of genes which have a least 5 counts in one of sample:  False    158612
# True      29014
# dtype: int64
# Number of all genes after data filtering:  32023
#                    OT_05  OT_17  OT_18  OT_21  OT_23  OT_33  OT_34  OT_62  \
# genes
# ENST00000390400.2      6     12      4      2      8      0      2      1
# ENST00000390468.1      4      7      4      4      5      5      2      5
# ENST00000390440.2      2      5      4      1      5      8      2      2
# ENST00000390436.2      4      5     12      4      6     11      7      6
# ENST00000390435.1      3     12     12      0     14      7      1      8
#
#                    OT_63  OT_64  OT_65  OT_66  OT_67  OT_69  OT_71
# genes
# ENST00000390400.2     12      5      5      5      6      2      6
# ENST00000390468.1      8      4     10      6      5      9      1
# ENST00000390440.2     17      5      7      0      3      3      4
# ENST00000390436.2      3      3     16      5      4      3      8
# ENST00000390435.1     14      4      8      5      4      9      0

# %%
# LEARN COEFFICIENT for MEAN & VARIANCE relation

x = samples.mean(axis=1).to_numpy()
y = samples.std(axis=1).to_numpy() **2
logx = np.ma.log(x)
logy = np.ma.log(y)
logx.filled(0)
logy.filled(0)
coeffs = np.polyfit(logx, logy, 2)

poly = np.poly1d(coeffs)
print(poly)

yfit = lambda xx: np.exp(poly(np.log(xx)))

plt.figure(figsize=(9.5, 5.5))
plt.loglog(x,y, 'b.', label='Real')
xline = np.append(np.arange(0, 1, 0.001), np.arange(1, 10e+5))
plt.loglog(xline,yfit(xline), 'g-', label='Estimated')
plt.title('Mean vs variance')
plt.xlabel('Mean gene expression level (log10 scale)')
plt.ylabel('Variance (log10 scale)')
plt.legend()
plt.show()

plt.figure(figsize=(9.5, 5.5))
plt.plot(x,y, 'b.', label='Real')
xline = np.append(np.arange(0, 1, 0.001), np.arange(1, 10e+5))
plt.plot(xline,poly(xline), 'g-', label='Estimated')
plt.plot(xline, 0.1162 * xline**2 + 0.8154 * xline + 0.545, '-')
plt.plot(xline, 0.06523 * xline**2 + 1.121 * xline + 0.235) # remove only 0
plt.xlim(0, 1000)
plt.ylim(0, 100000)
plt.title('Mean vs variance')
plt.xlabel('Mean gene expression level')
plt.ylabel('Variance')
plt.legend()
plt.show()

# 0.06523 x + 1.121 x + 0.235
# Out:
#          2
# 0.05315 x + 1.138 x + 0.08155
# <ipython-input-6-88c9bdb5ed47>:14: RuntimeWarning: divide by zero encountered in log
#   yfit = lambda xx: np.exp(poly(np.log(xx)))
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/numpy/lib/polynomial.py:734: RuntimeWarning: invalid value encountered in multiply
#   y = y * x + p[i]

# %%
# MEAN & VARIANCE relation
# 0.04519 x2 + 1.17 x + 0.1613
x = np.append(np.arange(0, 1, 0.001), np.arange(1, 10e+5))
print(x)
fig,ax = plt.subplots()
fig.set_size_inches(9.5, 5.5, forward=True)
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot(samples.mean(axis=1), samples.std(axis=1)**2, 'b.', label='Real')
ax.plot(x, x, 'g-', label='Poisson')
ax.plot(x, x + 0.1 * x**2, 'r-', label='Negative Binomial, p=0.1')
ax.plot(x, coeffs[0] * x**2 + coeffs[1] * x + coeffs[2], color='orange', label='Negative Binomial, p=0.5')
ax.plot(0.05, coeffs[0] * 0.05**2 + coeffs[1] * 0.05 + coeffs[2], 'ro')

# 0.04519 x2 + 1.17 x + 0.1613
ax.legend()
plt.title('Mean vs variance')
plt.xlabel('Mean gene expression level (log10 scale)')
plt.ylabel('Variance (log10 scale)')
plt.savefig('mean_vs_variance.png')
plt.show()
# Out:
# [0.00000e+00 1.00000e-03 2.00000e-03 ... 9.99997e+05 9.99998e+05
#  9.99999e+05]

# %%
h = samples.mean(axis=1)
bins = np.arange(80)

kde = gaussian_kde(h)
print(kde(3))
xx = np.linspace(0, 80, 1000)
fig, ax = plt.subplots(figsize=(8,6))
ax.hist(h, density=True, bins=bins, alpha=0.3)
ax.plot(xx, kde(xx))
# Out:
# [0.00206582]

# %%
h = samples.mean(axis=1)
import scipy.stats as stats
x1 = np.sort(h)
x1 = x1[:-4]
# print(x1)
kde = stats.gaussian_kde(x1)
xs = np.linspace(-10, np.max(x1), num=100)
y1 = kde(xs)

_, ax = plt.subplots()
# ax.plot(xs, y1, label='Scott (default)')
# ax.plot(xs, norm.pdf(xs, 3, 1.2), label='Normal')
print(h.mean(), h.to_numpy().std())
print(h)
ax.plot(xs, norm.pdf(xs, h.mean(), 20), label='Normal')
ax.hist(h, density=True, bins=bins, alpha=0.3)
# ax.plot(xs, y2, label='Silverman')
# ax.set_ylim(0, 0.01)
# ax.set_xlim(0, 200)
ax.legend()
plt.show()
# Out:
# 33.33981409195474 1517.500886949132
# genes
# ENST00000390400.2     5.066667
# ENST00000390468.1     5.266667
# ENST00000390440.2     4.533333
# ENST00000390436.2     6.466667
# ENST00000390435.1     6.733333
#                        ...
# ENST00000420084.1     2.600000
# ENST00000505946.2     5.733333
# ENST00000510138.2    19.533333
# ENST00000574122.1    10.800000
# ENST00000383620.4     4.266667
# Length: 32023, dtype: float64

# %% [markdown]
# ### Simulated data distribution

# %%
#9006 5839
# Show histogram of transcript
transcript_counts = samples.loc[samples.index[5639],:].to_numpy()
print(transcript_counts)
x = range(0, max(transcript_counts))
plt.hist(transcript_counts, color='orange', density=True)

mean = transcript_counts.mean()
std_real = transcript_counts.std()
std = np.sqrt(poly(transcript_counts.mean()))

p = mean/std**2
n = mean*p/(1.0 - p)
plt.plot(x, nbinom.pmf(x, n, p), label='Estimated')
print('Mean estimated: ', nbinom.mean(n, p))
print('Std estimated: ', nbinom.std(n, p))

p = mean/std_real**2
n = mean*p/(1.0 - p)
plt.plot(x, nbinom.pmf(x, n, p), label='Real')
print('Mean real: ', nbinom.mean(n, p))
print('Std real: ', nbinom.std(n, p))

plt.legend()
plt.show()
# Out:
# [3 2 1 4 3 2 0 2 5 5 7 4 1 2 4]
# Mean estimated:  3.0000000000000004
# Std estimated:  1.993142915803936
# Mean real:  2.999999999999995
# Std real:  1.7888543819998302

# %%
a, b, _ = rna_seq_generator(
        n_transcripts=10000,
        distribution="Negative binomial",
        n_STA=30, n_CR=15, n_OT=15,
        n_IS_effect=10, IS_effect=(0.5, 0.6),  # strong IS effect
        is_class_effect=False, n_class_effect=10, class_effect=(0.2, 0.2)  # class effect, normal distribution
)

# %%
x = samples.mean(axis=1).to_numpy()
y = samples.std(axis=1).to_numpy()**2
plt.plot(x[x<5000],y[x<5000], 'b.')

x = a.mean(axis=1).to_numpy()
y = a.std(axis=1).to_numpy()**2
plt.plot(x[x<5000],y[x<5000], 'r.')

plt.plot(np.arange(500), 0.06523 * np.arange(500) ** 2 + 1.121 * np.arange(500) + 0.235)
plt.xlim(-100, 1000)
plt.ylim(-1000, 1e+5)
# Out:
# (-1000.0, 100000.0)

# %%
x = samples.mean(axis=1).to_numpy().mean()
y = samples.std(axis=1).to_numpy().mean()
print(x, y)
OT_samples = samples.copy()
# Out:
# 6.327263101418069 3.0028969544177984

# %%
n_transcripts = 10000
# beta0 = kde.resample(n_transcripts)
# beta0 = beta0[0]
beta0 = np.exp(np.random.normal(3, 1.2, n_transcripts))
beta0[beta0<0]=0.001
counts = np.zeros((n_transcripts, 30), dtype=int)
for i in range(n_transcripts):
    mean = beta0[i]
    std = np.sqrt(0.06523 * mean**2 + 1.121 * mean + 0.235)
    p = mean / std ** 2
    n = mean * p / (1.0 - p)
    counts[i, :] = np.random.negative_binomial(n=n, p=p, size=30)
print(counts)
# Out:
# [[ 3  4  3 ...  2  5  6]
#  [ 6  8  4 ...  8  5 12]
#  [17 26 10 ... 19  9 20]
#  ...
#  [ 6 18 15 ... 11  8 11]
#  [ 9 20 22 ... 14 16 20]
#  [26 20 29 ... 25 33 25]]

# %%
x = samples.mean(axis=1).to_numpy()
y = samples.std(axis=1).to_numpy()**2
plt.plot(x[x<5000],y[x<5000], 'b.')

x = counts.mean(axis=1)
y = counts.std(axis=1)**2
plt.plot(x[x<5000],y[x<5000], 'r.')

# plt.plot(np.arange(600), 0.06523 * np.arange(600) ** 2 + 1.121 * np.arange(600) + 0.235, 'r-')
plt.xlim(-100, 2000)
plt.ylim(-1000, 1e+5)
# Out:
# (-1000.0, 100000.0)

# %% [markdown]
# ### Experiments
# #### Generate count data with POISSON distribution

# %%
# experiment settings
STA_range = [5, 10, 20, 50, 100, 200, 500, 1000, 2000, 5000]
n_repeats = 100
n_STA = STA_range[-1]  # maximal number of STA patients

# arrays for AUC results
mean_auc_results_origin = np.zeros((n_repeats, len(STA_range)))
mean_auc_results_expected = np.zeros((n_repeats, len(STA_range)))
mean_auc_results_filtered = np.zeros((n_repeats, len(STA_range)))

# %%
for j in range(n_repeats):
    a, b, c = rna_seq_generator(
        n_transcripts=100,
        distribution="Poisson",
        n_STA=n_STA, n_CR=15, n_OT=15,
        n_IS_effect=10, IS_effect=(0.5, 0.6),  # strong IS effect
        is_class_effect=False, n_class_effect=10, class_effect=(0.2, 0.2)  # class effect, normal distribution
    )
    patient_labels = a.columns

    for i in range(len(STA_range)):
        # leave only STA_range[i] STA patients
        a_tmp = a.drop(patient_labels[range(n_STA - STA_range[i])], axis=1)
        b_tmp = b.drop(patient_labels[range(n_STA - STA_range[i])], axis=1)
        c_tmp = c.drop(patient_labels[range(n_STA - STA_range[i])], axis=0)
        try:
            d, e, f = experiment(a_tmp, b_tmp, c_tmp, n_CR=15, distribution="Poisson")
            mean_auc_results_origin[j, i] = d.mean()
            mean_auc_results_expected[j, i] = e.mean()
            mean_auc_results_filtered[j, i] = f.mean()
        except: # when STA number is too small, there are the PerfectSeparation error
            # print('Exception for ', STA_range[i], ' STA patients.')
            mean_auc_results_origin[j, i] = np.nan
            mean_auc_results_expected[j, i] = np.nan
            mean_auc_results_filtered[j, i] = np.nan
# Out:
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/links.py:517: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/generalized_linear_model.py:1198: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)

# %%
indexes = range(n_repeats)

fig,ax = plt.subplots()
ax.set_xscale('log')
ax.set_xticks(STA_range)
ax.set_xticklabels(STA_range)

fig.set_size_inches(10, 6)

origin = ax.hlines(np.nanmean(mean_auc_results_origin[indexes]), STA_range[0],  STA_range[-1], colors=['magenta'], label='Origin')
ax.fill_between(STA_range, np.nanmean(mean_auc_results_origin[indexes]) - np.nanstd(mean_auc_results_origin[indexes])/np.sqrt(n_repeats), np.nanmean(mean_auc_results_origin[indexes]) + np.nanstd(mean_auc_results_origin[indexes])/np.sqrt(n_repeats),facecolor='pink', alpha= 0.5 )

filtered = ax.errorbar(STA_range, np.nanmean(mean_auc_results_filtered[indexes], axis=0), np.nanstd(mean_auc_results_filtered[indexes], axis=0)/np.sqrt(n_repeats), ecolor= 'black', fmt='-ok', capsize=5, label='Compensated') #green

expected = ax.hlines(np.nanmean(mean_auc_results_expected[indexes]),  STA_range[0],  STA_range[-1], colors=['orange'], label='Expected') #orange
ax.fill_between(STA_range, np.nanmean(mean_auc_results_expected[indexes]) - np.nanstd(mean_auc_results_expected[indexes])/np.sqrt(n_repeats), np.nanmean(mean_auc_results_expected[indexes]) + np.nanstd(mean_auc_results_expected[indexes])/np.sqrt(n_repeats),facecolor='orange', alpha= 0.3 )

ax.legend()
plt.title(n_repeats + ' repeats, 100 transcripts, no class effect, strong  IS effect, 15x OT, 15x CR')
plt.xlabel('Number of STA samples')
plt.ylabel('AUC score')
plt.show()
fig.savefig('SAVEFIG.png')

# %% [markdown]
# #### Generate count data with Negative binomial distribution

# %%
# experiment settings
STA_range = [10, 20, 50, 100, 200, 500, 1000, 2000] #, 5000] #, 10000]
n_repeats = 10
n_STA = STA_range[-1]  # maximal number of STA patients

# arrays for AUC results
mean_auc_results_origin = np.zeros((n_repeats, len(STA_range)))
mean_auc_results_expected = np.zeros((n_repeats, len(STA_range)))
mean_auc_results_filtered = np.zeros((n_repeats, len(STA_range)))

# %%
for j in range(n_repeats):
    a, b, c = rna_seq_generator(
        n_transcripts=1000,
        distribution="Negative binomial",
        n_STA=n_STA, n_CR=15, n_OT=15,
        n_IS_effect=5, IS_effect=(0.5, 0.9),  # weak IS effect
        is_class_effect=False, n_class_effect=5, class_effect=(0.3, 0.1)  # class effect, normal distribution
    )
    patient_labels = a.columns

    for i in range(len(STA_range)):
        # leave only STA_range[i] STA patients
        a_tmp = a.drop(patient_labels[range(n_STA - STA_range[i])], axis=1)
        b_tmp = b.drop(patient_labels[range(n_STA - STA_range[i])], axis=1)
        c_tmp = c.drop(patient_labels[range(n_STA - STA_range[i])], axis=0)
        try:
            d, e, f = experiment(a_tmp, b_tmp, c_tmp, n_CR=15, distribution="Negative binomial")
            mean_auc_results_origin[j, i] = d.mean()
            mean_auc_results_expected[j, i] = e.mean()
            mean_auc_results_filtered[j, i] = f.mean()
        except: # when STA number is too small, there are the PerfectSeparation error
            print('Exception when ', STA_range[i], ' STA samples.')
            mean_auc_results_origin[j, i] = np.nan
            mean_auc_results_expected[j, i] = np.nan
            mean_auc_results_filtered[j, i] = np.nan
# Out:
# Exception when  10  STA samples.
# Exception when  10  STA samples.
# Exception when  10  STA samples.
# /Users/karinabalagazova/miniconda3/envs/RPZ/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:1226: RuntimeWarning: invalid value encountered in true_divide
#   endog_mu = self._clean(endog / mu)

# %%
a, b, c = rna_seq_generator(
        n_transcripts=10000,
        distribution="Negative binomial",
        n_STA=30, n_CR=15, n_OT=15,
        n_IS_effect=5, IS_effect=(0.5, 0.9),  # weak IS effect
        is_class_effect=False, n_class_effect=5, class_effect=(0.3, 0.1)  # class effect, normal distribution
    )
x = samples.mean(axis=1).to_numpy()
y = samples.std(axis=1).to_numpy()**2
plt.plot(x[x<5000],y[x<5000], 'b.')

x = a.mean(axis=1)
y = a.std(axis=1)**2
plt.plot(x[x<5000],y[x<5000], 'r.')

# plt.plot(np.arange(600), 0.06523 * np.arange(600) ** 2 + 1.121 * np.arange(600) + 0.235, 'r-')
plt.xlim(-100, 2000)
plt.ylim(-1000, 1e+5)
# Out:
# (-1000.0, 100000.0)

# %%
indexes = range(n_repeats)

fig,ax = plt.subplots()
ax.set_xscale('log')
ax.set_xticks(STA_range)
ax.set_xticklabels(STA_range)

fig.set_size_inches(10, 6)

origin = ax.hlines(np.nanmean(mean_auc_results_origin[indexes]), STA_range[0],  STA_range[-1], colors=['magenta'], label='Origin')
ax.fill_between(STA_range, np.nanmean(mean_auc_results_origin[indexes]) - np.nanstd(mean_auc_results_origin[indexes])/np.sqrt(n_repeats), np.nanmean(mean_auc_results_origin[indexes]) + np.nanstd(mean_auc_results_origin[indexes])/np.sqrt(n_repeats),facecolor='pink', alpha= 0.5 )

filtered = ax.errorbar(STA_range, np.nanmean(mean_auc_results_filtered[indexes], axis=0), np.nanstd(mean_auc_results_filtered[indexes], axis=0)/np.sqrt(n_repeats), ecolor= 'black', fmt='-ok', capsize=5, label='Compensated') #green

expected = ax.hlines(np.nanmean(mean_auc_results_expected[indexes]),  STA_range[0],  STA_range[-1], colors=['orange'], label='Expected') #orange
ax.fill_between(STA_range, np.nanmean(mean_auc_results_expected[indexes]) - np.nanstd(mean_auc_results_expected[indexes])/np.sqrt(n_repeats), np.nanmean(mean_auc_results_expected[indexes]) + np.nanstd(mean_auc_results_expected[indexes])/np.sqrt(n_repeats),facecolor='orange', alpha= 0.3 )

ax.legend()
plt.title('20 repeats, 100 transcripts, class effect, weak IS effect, 15x OT, 15x CR')
plt.xlabel('Number of STA samples')
plt.ylabel('AUC score')
plt.savefig('SAVEFIG7.png')
plt.show()

# %%
print(np.nanmean(mean_auc_results_origin[indexes]))
print(np.nanmean(mean_auc_results_expected[indexes]))
# Out:
# 0.7333333333333333
# 0.6770833333333333

# %%
mean_auc_results_origin1 = mean_auc_results_origin.copy()
mean_auc_results_expected1 = mean_auc_results_expected.copy()
mean_auc_results_filtered1 = mean_auc_results_filtered.copy()

# %%
print(mean_auc_results_origin)
print(mean_auc_results_origin1)
print(np.hstack((mean_auc_results_origin1, mean_auc_results_origin)))
# Out:
# [[0.58333333]
#  [0.58333333]
#  [0.5       ]
#  [0.375     ]
#  [0.79166667]
#  [0.66666667]
#  [0.45833333]
#  [0.91666667]
#  [0.70833333]
#  [0.79166667]]
# [[0.375      0.625      0.5        0.41666667 0.5        0.5
#   0.5        0.375     ]
#  [0.91666667 0.91666667 0.875      0.83333333 0.91666667 0.875
#   0.875      0.91666667]
#  [0.875      0.95833333 0.91666667 0.83333333 1.         0.95833333
#   0.875      0.95833333]
#  [0.83333333 0.79166667 0.75       0.58333333 0.75       0.79166667
#   0.75       0.79166667]
#  [0.83333333 0.91666667 0.75       0.79166667 0.83333333 0.83333333
#   0.875      0.83333333]
#  [0.79166667 0.75       0.875      0.91666667 0.83333333 0.79166667
#   0.91666667 1.        ]
#  [0.79166667 0.91666667 0.79166667 0.875      0.875      0.875
#   0.91666667 0.875     ]
#  [0.70833333 0.75       0.70833333 0.70833333 0.66666667 0.79166667
#   0.79166667 0.83333333]
#  [0.83333333 0.91666667 0.91666667 0.91666667 0.83333333 0.95833333
#   0.83333333 0.83333333]
#  [0.75       1.         1.         0.91666667 0.875      0.91666667
#   0.95833333 0.875     ]]
# [[0.375      0.625      0.5        0.41666667 0.5        0.5
#   0.5        0.375      0.58333333]
#  [0.91666667 0.91666667 0.875      0.83333333 0.91666667 0.875
#   0.875      0.91666667 0.58333333]
#  [0.875      0.95833333 0.91666667 0.83333333 1.         0.95833333
#   0.875      0.95833333 0.5       ]
#  [0.83333333 0.79166667 0.75       0.58333333 0.75       0.79166667
#   0.75       0.79166667 0.375     ]
#  [0.83333333 0.91666667 0.75       0.79166667 0.83333333 0.83333333
#   0.875      0.83333333 0.79166667]
#  [0.79166667 0.75       0.875      0.91666667 0.83333333 0.79166667
#   0.91666667 1.         0.66666667]
#  [0.79166667 0.91666667 0.79166667 0.875      0.875      0.875
#   0.91666667 0.875      0.45833333]
#  [0.70833333 0.75       0.70833333 0.70833333 0.66666667 0.79166667
#   0.79166667 0.83333333 0.91666667]
#  [0.83333333 0.91666667 0.91666667 0.91666667 0.83333333 0.95833333
#   0.83333333 0.83333333 0.70833333]
#  [0.75       1.         1.         0.91666667 0.875      0.91666667
#   0.95833333 0.875      0.79166667]]

# %%
mean_auc_results_origin1 = np.hstack((mean_auc_results_origin1, mean_auc_results_origin))
mean_auc_results_expected1 = np.hstack((mean_auc_results_expected1, mean_auc_results_expected))
mean_auc_results_filtered1 = np.hstack((mean_auc_results_filtered1, mean_auc_results_filtered))

# %%
mean_auc_results_origin = mean_auc_results_origin1.copy()
mean_auc_results_expected = mean_auc_results_expected1.copy()
mean_auc_results_filtered = mean_auc_results_filtered1.copy()
